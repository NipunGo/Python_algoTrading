# %% [markdown]
# # Finance & Analytics Club
#
# First go to https://www.alphavantage.co/ and get your FREE API key, please store the key somewhere for future use!
#
# Then go to https://github.com/RomelTorres/alpha_vantage and install the python module by following the steps given, you can do a lot of other stuffs, the whole documentation is given here!

# %% [markdown]
# Import necessary libraries

# %%
from alpha_vantage.timeseries import TimeSeries
import pandas as pd
import matplotlib.pyplot as plt

# %%
ts = TimeSeries(key='VXT99GSVWXLTSF01', output_format='pandas') # your key goes here
data, meta_data = ts.get_intraday(symbol='MSFT', interval='1min', outputsize='full') # returns data in python tuple

# %%
data
# Out:
#                       1. open   2. high   3. low  4. close  5. volume
# date
# 2020-03-31 16:00:00  157.4400  158.3800  157.430  157.6500  1010116.0
# 2020-03-31 15:59:00  157.5300  157.7900  157.380  157.4300   388180.0
# 2020-03-31 15:58:00  157.8500  157.9352  157.390  157.5300   310538.0
# 2020-03-31 15:57:00  158.0600  158.1500  157.800  157.8552   237027.0
# 2020-03-31 15:56:00  157.8900  158.4400  157.590  158.0900   494003.0
# ...                       ...       ...      ...       ...        ...
# 2020-03-25 09:35:00  149.3750  149.3750  149.375  149.3750   271589.0
# 2020-03-25 09:34:00  149.1648  149.7350  148.850  149.5400   364786.0
# 2020-03-25 09:33:00  148.3400  150.0000  147.900  149.2000   255336.0
# 2020-03-25 09:32:00  147.8100  148.9300  147.620  148.4699   198627.0
# 2020-03-25 09:31:00  148.9100  149.0000  147.550  147.6500  2073133.0
#
# [1945 rows x 5 columns]

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (1min) open, high, low, close prices and volume',
#  '2. Symbol': 'MSFT',
#  '3. Last Refreshed': '2020-03-31 16:00:00',
#  '4. Interval': '1min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %% [markdown]
# ### Similarly, you can also get intraday data for, let's say 50 stocks, from the method as mentioned in Pandas Data-reader notebook, I just want you to try it, ALL THE BEST!

# %%
ts = TimeSeries(key='VXT99GSVWXLTSF01', output_format='pandas') # your key goes here
data, meta_data = ts.get_intraday(symbol='BRITANNIA.NS', interval='1min', outputsize='full')

# %%
data
# Out:
#                        1. open    2. high     3. low   4. close  5. volume
# date
# 2020-04-01 05:59:00  2561.0500  2565.0000  2560.0000  2565.0000     1734.0
# 2020-04-01 05:58:00  2560.9500  2565.0000  2560.5500  2564.9500     1598.0
# 2020-04-01 05:57:00  2560.0000  2563.1499  2559.0000  2560.3501     1378.0
# 2020-04-01 05:56:00  2559.1001  2560.3501  2559.0500  2560.0000     1626.0
# 2020-04-01 05:55:00  2563.1499  2563.1499  2559.0000  2559.1001     1565.0
# ...                        ...        ...        ...        ...        ...
# 2020-03-25 23:49:00  2446.5500  2459.2000  2446.1001  2454.5500     1844.0
# 2020-03-25 23:48:00  2436.5500  2452.1001  2435.3501  2446.7000     1691.0
# 2020-03-25 23:47:00  2431.0000  2447.9500  2417.3000  2435.3999     3605.0
# 2020-03-25 23:46:00  2475.0000  2495.0000  2448.0000  2448.0000    10532.0
# 2020-03-25 23:45:00  2471.5500  2499.8999  2471.4500  2475.1001        0.0
#
# [1873 rows x 5 columns]

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (1min) open, high, low, close prices and volume',
#  '2. Symbol': 'BRITANNIA.NS',
#  '3. Last Refreshed': '2020-04-01 05:59:00',
#  '4. Interval': '1min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %%
data['5. volume'].plot()
plt.tight_layout()
plt.grid()
plt.show()

# %%
tickers = ["HINDUNILVR.NS","HDFC.NS","ITC.NS","ICICIBANK.NS","M&M.NS"]

# %%
stocks = pd.DataFrame()

# %%
for i in range(len(tickers)):
    ts = TimeSeries(key='VXT99GSVWXLTSF01', output_format='pandas') # your key goes here
    data, meta_data = ts.get_intraday(symbol=tickers[i], interval='1min', outputsize='full')
    stocks[tickers[i]] = data['4. close']

# %%
stocks
# Out:
#                      HINDUNILVR.NS  HDFC.NS  ITC.NS  ICICIBANK.NS  M&M.NS
# date
# 2020-04-01 05:59:00      2179.6499  1589.95  166.70        311.70     NaN
# 2020-04-01 05:58:00      2177.8999  1586.50  166.65        311.20     NaN
# 2020-04-01 05:57:00      2180.3000  1587.05  166.50        311.45     NaN
# 2020-04-01 05:56:00      2178.8501  1582.60  166.50        312.00     NaN
# 2020-04-01 05:55:00      2181.0000  1585.70  166.00        311.75     NaN
# ...                            ...      ...     ...           ...     ...
# 2020-03-25 23:49:00      2085.0000  1686.45  144.50        316.50     NaN
# 2020-03-25 23:48:00      2090.0000  1690.00  145.20        317.95     NaN
# 2020-03-25 23:47:00      2082.8000  1694.70  145.75        320.55     NaN
# 2020-03-25 23:46:00      2078.5500  1695.65  144.35        319.35     NaN
# 2020-03-25 23:45:00      2088.5500  1682.05  147.10        319.10     NaN
#
# [1872 rows x 5 columns]

# %%
stocks = stocks.drop(axis=1,columns='M&M.NS')

# %%
stocks
# Out:
#                      HINDUNILVR.NS  HDFC.NS  ITC.NS  ICICIBANK.NS
# date
# 2020-04-01 05:59:00      2179.6499  1589.95  166.70        311.70
# 2020-04-01 05:58:00      2177.8999  1586.50  166.65        311.20
# 2020-04-01 05:57:00      2180.3000  1587.05  166.50        311.45
# 2020-04-01 05:56:00      2178.8501  1582.60  166.50        312.00
# 2020-04-01 05:55:00      2181.0000  1585.70  166.00        311.75
# ...                            ...      ...     ...           ...
# 2020-03-25 23:49:00      2085.0000  1686.45  144.50        316.50
# 2020-03-25 23:48:00      2090.0000  1690.00  145.20        317.95
# 2020-03-25 23:47:00      2082.8000  1694.70  145.75        320.55
# 2020-03-25 23:46:00      2078.5500  1695.65  144.35        319.35
# 2020-03-25 23:45:00      2088.5500  1682.05  147.10        319.10
#
# [1872 rows x 4 columns]
